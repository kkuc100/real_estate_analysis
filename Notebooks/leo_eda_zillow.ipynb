# %%
# standard libraries
import pandas as pd
import numpy as np
import os
import random

# visualizations
import matplotlib.pyplot as plt
from IPython.display import Image
from mlxtend.plotting import heatmap
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
# %matplotlib inline

# sklearn
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

# tf
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import initializers

# datetime for manipulating date and time
import datetime

# scipy
import scipy.stats as stats
from scipy.optimize import curve_fit

random.seed(2)

# %% [markdown]
# ## Data Processing

# %%
# Load data
df_zillow_day = pd.read_csv("../Data/zillow_median_days_to_pending.csv")
df_zillow_listing = pd.read_csv("../Data/zillow_new_listings.csv")
df_zillow_day.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2018-01-06
# 0    102001         0    United States    country       NaN        55.0  \
# 1    394913         1     New York, NY        msa        NY        84.0
# 2    753899         2  Los Angeles, CA        msa        CA        34.0
# 3    394463         3      Chicago, IL        msa        IL        73.0
# 4    394514         4       Dallas, TX        msa        TX        41.0
#
#    2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  2024-07-06
# 0        51.0        46.0        44.0        35.0  ...        16.0  \
# 1        87.0        86.0        94.0        78.0  ...        24.0
# 2        30.0        18.0        16.0        15.0  ...        14.0
# 3        62.0        59.0        55.0        37.0  ...         8.0
# 4        40.0        39.0        35.0        27.0  ...        21.0
#
#    2024-07-13  2024-07-20  2024-07-27  2024-08-03  2024-08-10  2024-08-17
# ...

# %%
#basic eda
np.shape(df_zillow_daay)
# Out:
# (337, 354)

# %%
#basic
data_sample = df_zillow_day.iloc[1, 5:]
plt.figure(figsize=(10, 6))
plt.scatter(data_sample.index, data_sample.values, color='blue', alpha=0.7, edgecolor='black')
plt.title('Median days to pending sales from 2018 to now')
#plt.xlabel('Median Listing Price')
plt.ylabel('Days on the market')
plt.grid(axis='y', alpha=0.75)
plt.show()
